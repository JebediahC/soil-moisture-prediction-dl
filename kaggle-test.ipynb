# %%
import yaml

with open('config/config.yaml', 'r') as f:
    config = yaml.safe_load(f)

config['run_name'] = 'kaggle_run_3'
config['batch_size'] = 8
config['raw_path'] = '/kaggle/input/era5-2020-2024/data'  
config['raw_folder'] = '/kaggle/input/era5-2020-2024/data'  
config['log_path'] = 'logs/logger_training.log'
config['epochs'] = 150
config['model_type'] = "3dcnn_lstm"

config['months'] = ["2020-1", "2020-2", "2020-3", "2020-4", "2020-5", "2020-6", "2020-7", "2020-8", "2020-9", "2020-10", "2020-11", "2020-12", "2021-1", "2021-2", "2021-3", "2021-4", "2021-5", "2021-6", "2021-7", "2021-8", "2021-9", "2021-10", "2021-11", "2021-12", "2022-1", "2022-2", "2022-3", "2022-4", "2022-5", "2022-6", "2022-7", "2022-8", "2022-9", "2022-10", "2022-11", "2022-12"]


with open('config/config.yaml', 'w') as f:
    yaml.safe_dump(config, f, allow_unicode=True)

print('配置已更新:', config)
# Out:
# 配置已更新: {'model': 'empty_model', 'per_year_outputs_path': '/mnt/c/Users/jebediahc/OneDrive/鱼丸车仔/TUM-before-arrival/Project Earth Observation Data Analysis/Project-files-Soil-Moisture/per_year_outputs/', 'date': '2020-01-15', 'raw_path': 'data/raw', 'processed_path': 'data/processed', 'demo_path': 'data/demo', 'demo_nc_path': 'data/demo/2020-1.nc', 'demo_datetime': '2020-01-01T12:00:00', 'months': ['2020-1', '2020-2', '2020-3', '2020-4'], 'run_name': 'kaggle_test_run_1', 'raw_folder': 'data/raw', 'intermediate_folder': 'data/processed', 'use_channels': ['swvl1', 'ro', 'e', 'tp'], 'input_days': 20, 'predict_days': 10, 'batch_size': 4, 'epochs': 100}

# %%
# !python train.py
# Out:
# [2025-07-21 23:36:31.583] [INFO] Using config:
# {
#   "model": "empty_model",
#   "per_year_outputs_path": "/mnt/c/Users/jebediahc/OneDrive/鱼丸车仔/TUM-before-arrival/Project Earth Observation Data Analysis/Project-files-Soil-Moisture/per_year_outputs/",
#   "date": "2020-01-15",
#   "raw_path": "please_specify_raw_path",
#   "processed_path": "data/processed",
#   "demo_path": "data/demo",
#   "demo_nc_path": "data/demo/2020-1.nc",
#   "demo_datetime": "2020-01-01T12:00:00",
#   "months": [
#     "2020-1",
#     "2020-2",
#     "2020-3",
#     "2020-4",
#     "2020-5",
#     "2020-6",
#     "2020-7"
#   ],
#   "run_name": "test-untiled",
#   "raw_folder": "data/raw",
#   "intermediate_folder": "data/processed",
#   "use_channels": [
#     "swvl1",
#     "ro",
#     "e",
#     "tp"
#   ],
#   "input_days": 20,
#   "predict_days": 10,
#   "batch_size": 0,
#   "epochs": 100
# }
# <xarray.Dataset> Size: 3GB
# Dimensions:     (valid_time: 744, latitude: 371, longitude: 701)
# Coordinates:
# ...
